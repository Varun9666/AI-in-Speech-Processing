# %%
import librosa
import soundfile as sf
import IPython.display as ipd
import matplotlib.pyplot as plt

input_audio, sample_rate = librosa.load('Varun.wav', sr=None)
trimmed_audio, trim_index = librosa.effects.trim(input_audio)
sf.write('trimmed_audio.wav', trimmed_audio, sample_rate)
trimmed, trimmed_sr = librosa.load('trimmed_audio.wav', sr=None)

print("Input Audio:")
ipd.display(ipd.Audio(input_audio, rate=sample_rate))

plt.figure(figsize=(10, 5))
librosa.display.waveshow(input_audio, sr=sample_rate)
plt.title('Original')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()

print("Trimmed Audio:")
ipd.display(ipd.Audio(trimmed_audio, rate=sample_rate))

plt.figure(figsize=(10, 5))
librosa.display.waveshow(trimmed, sr=trimmed_sr)
plt.title('Trimmed')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Input Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Trimmed Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
